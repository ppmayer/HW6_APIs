# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The weather becomes warmer as one approaches the equator (0 Deg. Latitude). However, the southern hemisphere (-60 to 0 degrees) seems to be warmer this time of year (3/23/2019) than the northern hemisphere (0 to 80 degrees).
# * There is no strong relationship between latitude and cloudiness. However, there are less cities with zero cloudiness between -20 and 0 degrees than for the rest of the latitude range.
# * There is no strong relationship between latitude and wind speed. However, higher wind speeds exist in the northern hemisphere than in the southern hemisphere.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_df=pd.DataFrame(columns={"City":[],
            "Cloudiness":[],
            "Country":[],
            "Date":[],
            "Humidity":[],
            "Lat":[],
            "Lng":[],
            "Max Temp":[],
            "Min Temp":[], 
            "Avg Temp":[],                     
            "Wind Speed":[]
           },index=[i for i in range(len(cities))])
weather_df.head()
# Out:
#   City Cloudiness Country Date Humidity  Lat  Lng Max Temp Min Temp Avg Temp  \
# 0  NaN        NaN     NaN  NaN      NaN  NaN  NaN      NaN      NaN      NaN
# 1  NaN        NaN     NaN  NaN      NaN  NaN  NaN      NaN      NaN      NaN
# 2  NaN        NaN     NaN  NaN      NaN  NaN  NaN      NaN      NaN      NaN
# 3  NaN        NaN     NaN  NaN      NaN  NaN  NaN      NaN      NaN      NaN
# 4  NaN        NaN     NaN  NaN      NaN  NaN  NaN      NaN      NaN      NaN
#
#   Wind Speed
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
#see API output

settings = {
    "units": "metric",
    "appid": api_key,
    "q" : cities[0]
}
response = requests.get(base_url, params=settings)
response=response.json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 7.07, 'lon': -73.85},
#  'dt': 1553374800,
#  'id': 3689169,
#  'main': {'humidity': 78,
#           'pressure': 1009,
#           'temp': 28,
#           'temp_max': 28,
#           'temp_min': 28},
#  'name': 'Barrancabermeja',
#  'sys': {'country': 'CO',
#          'id': 8568,
#          'message': 0.0038,
#          'sunrise': 1553338688,
#          'sunset': 1553382349,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 27.0016, 'speed': 1.12}}

# %%
#make API calls for all cities

base_url= "http://api.openweathermap.org/data/2.5/weather?"

i=0
record_index=0
for city in cities:
    try:
        settings = {
            "units": "metric",
            "appid": api_key,
            "q" : city
        }
        response = requests.get(base_url, params=settings)
        response=response.json()
        print(f"Processing Record {record_index+1} | {city}")
        cloudiness=response['clouds']['all']
        country=response['sys']['country']
        date=response['dt']
        humidity=response['main']['humidity']
        lat=response['coord']['lat']
        lng=response['coord']['lon']
        max_temp=response['main']['temp_max']
        min_temp=response['main']['temp_min']
        avg_temp=response['main']['temp']
        wind_speed=response['wind']['speed']
        weather_df['City'].iloc[i]=city
        weather_df['Cloudiness'].iloc[i]=cloudiness
        weather_df['Country'].iloc[i]=country
        weather_df['Date'].iloc[i]=date
        weather_df['Humidity'].iloc[i]=humidity
        weather_df['Lat'].iloc[i]=lat
        weather_df['Lng'].iloc[i]=lng
        weather_df['Max Temp'].iloc[i]=max_temp
        weather_df['Min Temp'].iloc[i]=min_temp
        weather_df['Avg Temp'].iloc[i]=avg_temp
        weather_df['Wind Speed'].iloc[i]=wind_speed
        i=i+1
        record_index=record_index+1
    except:
        print("City not found. Skipping...")
        record_index=record_index+1
# Out:
# Processing Record 1 | barrancabermeja
# Processing Record 2 | hilo
# Processing Record 3 | cidreira
# Processing Record 4 | georgetown
# Processing Record 5 | impfondo
# Processing Record 6 | rikitea
# Processing Record 7 | voyvozh
# Processing Record 8 | namibe
# Processing Record 9 | torbay
# Processing Record 10 | chimore
# Processing Record 11 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 | hasaki
# Processing Record 13 | pyshma
# Processing Record 14 | bredasdorp
# Processing Record 15 | mogadishu
# Processing Record 16 | busselton
# Processing Record 17 | hermanus
# Processing Record 18 | saskylakh
# Processing Record 19 | new norfolk
# Processing Record 20 | praia da vitoria
# Processing Record 21 | hobart
# Processing Record 22 | sao joao da barra
# Processing Record 23 | cape town
# Processing Record 24 | sarakhs
# Processing Record 25 | punta arenas
# Processing Record 26 | barrow
# Processing Record 27 | puerto ayora
# Processing Record 28 | albany
# Processing Record 29 | mys shmidta
# City not found. Skipping...
# Processing Record 30 | taolanaro
# City not found. Skipping...
# Processing Record 31 | sitka
# Processing Record 32 | russell
# Processing Record 33 | jamestown
# Processing Record 34 | cherdyn
# Processing Record 35 | mackenzie
# Processing Record 36 | dikson
# Processing Record 37 | tasiilaq
# Processing Record 38 | bowen
# Processing Record 39 | leningradskiy
# Processing Record 40 | ushuaia
# Processing Record 41 | amderma
# City not found. Skipping...
# Processing Record 42 | pemangkat
# City not found. Skipping...
# Processing Record 43 | cap malheureux
# Processing Record 44 | kibala
# Processing Record 45 | barentsburg
# City not found. Skipping...
# Processing Record 46 | salalah
# Processing Record 47 | east london
# Processing Record 48 | victoria
# Processing Record 49 | cherskiy
# Processing Record 50 | codrington
# Processing Record 51 | talnakh
# Processing Record 52 | kiriakion
# City not found. Skipping...
# Processing Record 53 | mount gambier
# Processing Record 54 | ambovombe
# Processing Record 55 | mataura
# Processing Record 56 | road town
# Processing Record 57 | balaghat
# Processing Record 58 | upernavik
# Processing Record 59 | saldanha
# Processing Record 60 | avarua
# Processing Record 61 | attawapiskat
# City not found. Skipping...
# Processing Record 62 | airai
# Processing Record 63 | nouadhibou
# Processing Record 64 | ostrovnoy
# Processing Record 65 | vestmannaeyjar
# Processing Record 66 | richards bay
# Processing Record 67 | marcona
# City not found. Skipping...
# Processing Record 68 | ribeira grande
# Processing Record 69 | chitungwiza
# Processing Record 70 | cairns
# Processing Record 71 | saint-philippe
# Processing Record 72 | sentyabrskiy
# City not found. Skipping...
# Processing Record 73 | kaitangata
# Processing Record 74 | manbij
# Processing Record 75 | herat
# Processing Record 76 | atuona
# Processing Record 77 | kavaratti
# Processing Record 78 | esil
# Processing Record 79 | khatanga
# Processing Record 80 | guerrero negro
# Processing Record 81 | mar del plata
# Processing Record 82 | arlit
# Processing Record 83 | vaini
# Processing Record 84 | naze
# Processing Record 85 | tasbuget
# City not found. Skipping...
# Processing Record 86 | belushya guba
# City not found. Skipping...
# Processing Record 87 | provideniya
# Processing Record 88 | springbok
# Processing Record 89 | ponta do sol
# Processing Record 90 | kodiak
# Processing Record 91 | inirida
# Processing Record 92 | batagay
# Processing Record 93 | vangaindrano
# Processing Record 94 | amlagora
# Processing Record 95 | salinopolis
# Processing Record 96 | mount isa
# Processing Record 97 | lolua
# City not found. Skipping...
# Processing Record 98 | kapaa
# Processing Record 99 | birjand
# Processing Record 100 | katobu
# Processing Record 101 | vila velha
# Processing Record 102 | klaksvik
# Processing Record 103 | vaitupu
# City not found. Skipping...
# Processing Record 104 | tura
# Processing Record 105 | maryborough
# Processing Record 106 | vredendal
# Processing Record 107 | soure
# Processing Record 108 | bluff
# Processing Record 109 | tatawin
# City not found. Skipping...
# Processing Record 110 | beloha
# Processing Record 111 | qaanaaq
# Processing Record 112 | namtsy
# Processing Record 113 | saint-joseph
# Processing Record 114 | necochea
# Processing Record 115 | kuala terengganu
# Processing Record 116 | clyde river
# Processing Record 117 | nouakchott
# Processing Record 118 | longyearbyen
# Processing Record 119 | redcliffe
# Processing Record 120 | tuktoyaktuk
# Processing Record 121 | yulara
# Processing Record 122 | ancud
# Processing Record 123 | sinjar
# Processing Record 124 | souillac
# Processing Record 125 | heubach
# Processing Record 126 | port elizabeth
# Processing Record 127 | butaritari
# Processing Record 128 | passo de camaragibe
# Processing Record 129 | yellowknife
# Processing Record 130 | mahebourg
# Processing Record 131 | lucapa
# Processing Record 132 | hay river
# Processing Record 133 | auras
# Processing Record 134 | port alfred
# Processing Record 135 | touros
# Processing Record 136 | praya
# Processing Record 137 | nizhniy kuranakh
# Processing Record 138 | kruisfontein
# Processing Record 139 | chor
# Processing Record 140 | kahului
# Processing Record 141 | bathsheba
# Processing Record 142 | brookhaven
# Processing Record 143 | chapais
# Processing Record 144 | hithadhoo
# Processing Record 145 | hamilton
# Processing Record 146 | roald
# Processing Record 147 | katsuura
# Processing Record 148 | virginia beach
# Processing Record 149 | karamay
# City not found. Skipping...
# Processing Record 150 | selvik
# Processing Record 151 | conceicao do mato dentro
# Processing Record 152 | crab hill
# City not found. Skipping...
# Processing Record 153 | griffith
# Processing Record 154 | pitimbu
# Processing Record 155 | maningrida
# Processing Record 156 | puerto penasco
# Processing Record 157 | chachapoyas
# Processing Record 158 | hammerfest
# Processing Record 159 | bengkulu
# City not found. Skipping...
# Processing Record 160 | pacific grove
# Processing Record 161 | petropavlovsk-kamchatskiy
# Processing Record 162 | arraial do cabo
# Processing Record 163 | maniitsoq
# Processing Record 164 | mecca
# Processing Record 165 | ozernovskiy
# Processing Record 166 | camocim
# Processing Record 167 | tsihombe
# City not found. Skipping...
# Processing Record 168 | lhuntshi
# City not found. Skipping...
# Processing Record 169 | beringovskiy
# Processing Record 170 | alpena
# Processing Record 171 | anchorage
# Processing Record 172 | tiksi
# Processing Record 173 | kieta
# Processing Record 174 | waddan
# Processing Record 175 | annonay
# Processing Record 176 | san policarpo
# Processing Record 177 | maxixe
# Processing Record 178 | raudeberg
# Processing Record 179 | nizhneyansk
# City not found. Skipping...
# Processing Record 180 | lar
# Processing Record 181 | melbourne
# Processing Record 182 | saint george
# Processing Record 183 | vigrestad
# Processing Record 184 | wyndham
# Processing Record 185 | benguela
# Processing Record 186 | lakes entrance
# Processing Record 187 | dolores
# Processing Record 188 | nishihara
# Processing Record 189 | louisbourg
# City not found. Skipping...
# Processing Record 190 | santa rosa
# Processing Record 191 | dejen
# Processing Record 192 | markova
# Processing Record 193 | verkhnyaya sinyachikha
# Processing Record 194 | coihaique
# Processing Record 195 | sulangan
# Processing Record 196 | portland
# Processing Record 197 | greenfield
# Processing Record 198 | petropavlovka
# Processing Record 199 | broome
# Processing Record 200 | paraiso
# Processing Record 201 | antofagasta
# Processing Record 202 | alice springs
# Processing Record 203 | tumannyy
# City not found. Skipping...
# Processing Record 204 | porto novo
# Processing Record 205 | ijaki
# City not found. Skipping...
# Processing Record 206 | severo-kurilsk
# Processing Record 207 | grand gaube
# Processing Record 208 | zarubino
# Processing Record 209 | buchanan
# Processing Record 210 | iowa city
# Processing Record 211 | dingle
# Processing Record 212 | mazatan
# City not found. Skipping...
# Processing Record 213 | thompson
# Processing Record 214 | meulaboh
# Processing Record 215 | loikaw
# Processing Record 216 | staryy biser
# City not found. Skipping...
# Processing Record 217 | bethel
# Processing Record 218 | samarai
# Processing Record 219 | maputo
# Processing Record 220 | dharmanagar
# Processing Record 221 | utete
# Processing Record 222 | krasnaya gora
# Processing Record 223 | bardsir
# Processing Record 224 | slave lake
# Processing Record 225 | brus laguna
# Processing Record 226 | san patricio
# Processing Record 227 | castro
# Processing Record 228 | marsh harbour
# Processing Record 229 | kerrobert
# Processing Record 230 | yaan
# Processing Record 231 | isangel
# Processing Record 232 | grand river south east
# City not found. Skipping...
# Processing Record 233 | phalombe
# Processing Record 234 | hambantota
# Processing Record 235 | camacha
# Processing Record 236 | deep river
# Processing Record 237 | beian
# Processing Record 238 | ozgon
# City not found. Skipping...
# Processing Record 239 | deputatskiy
# Processing Record 240 | chara
# Processing Record 241 | pevek
# Processing Record 242 | lata
# Processing Record 243 | sibolga
# Processing Record 244 | nagtipunan
# Processing Record 245 | loyabad
# City not found. Skipping...
# Processing Record 246 | saint-michel-des-saints
# Processing Record 247 | vardo
# Processing Record 248 | skagastrond
# City not found. Skipping...
# Processing Record 249 | vila franca do campo
# Processing Record 250 | norman wells
# Processing Record 251 | saint anthony
# Processing Record 252 | burnie
# Processing Record 253 | paamiut
# Processing Record 254 | dakar
# Processing Record 255 | sur
# Processing Record 256 | lagoa
# Processing Record 257 | bonavista
# Processing Record 258 | mayor pablo lagerenza
# Processing Record 259 | port lincoln
# Processing Record 260 | maragogi
# Processing Record 261 | abha
# Processing Record 262 | dok kham tai
# Processing Record 263 | puerto quijarro
# Processing Record 264 | tiznit
# Processing Record 265 | oxbow
# Processing Record 266 | killybegs
# Processing Record 267 | sladkovo
# Processing Record 268 | hailar
# Processing Record 269 | lorengau
# Processing Record 270 | kamenskoye
# City not found. Skipping...
# Processing Record 271 | marzuq
# Processing Record 272 | port hedland
# Processing Record 273 | fairbanks
# Processing Record 274 | te anau
# Processing Record 275 | belle fourche
# Processing Record 276 | hundested
# Processing Record 277 | atar
# Processing Record 278 | yumen
# Processing Record 279 | ussel
# Processing Record 280 | muravlenko
# Processing Record 281 | wattegama
# Processing Record 282 | yugorsk
# Processing Record 283 | carnarvon
# Processing Record 284 | lodja
# Processing Record 285 | constitucion
# Processing Record 286 | arboletes
# Processing Record 287 | iqaluit
# Processing Record 288 | wencheng
# Processing Record 289 | lompoc
# Processing Record 290 | tingi
# Processing Record 291 | samarinda
# Processing Record 292 | aksu
# Processing Record 293 | danielskuil
# Processing Record 294 | ketchenery
# City not found. Skipping...
# Processing Record 295 | samusu
# City not found. Skipping...
# Processing Record 296 | alashtar
# City not found. Skipping...
# Processing Record 297 | banda aceh
# Processing Record 298 | quelimane
# Processing Record 299 | nikolskoye
# Processing Record 300 | qaqortoq
# Processing Record 301 | yar-sale
# Processing Record 302 | okhotsk
# Processing Record 303 | payakumbuh
# Processing Record 304 | sorong
# Processing Record 305 | astaneh-ye ashrafiyeh
# Processing Record 306 | cervo
# Processing Record 307 | jamundi
# Processing Record 308 | erzin
# Processing Record 309 | umm kaddadah
# Processing Record 310 | caibarien
# Processing Record 311 | walvis bay
# Processing Record 312 | aklavik
# Processing Record 313 | mayo
# Processing Record 314 | cockburn town
# Processing Record 315 | avera
# Processing Record 316 | bethanien
# Processing Record 317 | stokmarknes
# Processing Record 318 | tari
# Processing Record 319 | mao
# Processing Record 320 | tocopilla
# Processing Record 321 | cabo san lucas
# Processing Record 322 | hami
# Processing Record 323 | warqla
# City not found. Skipping...
# Processing Record 324 | baruun-urt
# Processing Record 325 | utiroa
# City not found. Skipping...
# Processing Record 326 | paris
# Processing Record 327 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 328 | taos
# Processing Record 329 | manzil tamim
# City not found. Skipping...
# Processing Record 330 | port blair
# Processing Record 331 | ixtapa
# Processing Record 332 | tual
# Processing Record 333 | roma
# Processing Record 334 | coquimbo
# Processing Record 335 | chuy
# Processing Record 336 | tyumen
# Processing Record 337 | taoudenni
# Processing Record 338 | aleksandrov gay
# Processing Record 339 | lebu
# Processing Record 340 | guerrero
# Processing Record 341 | san cristobal
# Processing Record 342 | pangnirtung
# Processing Record 343 | ouargaye
# Processing Record 344 | morgan city
# Processing Record 345 | barranca
# Processing Record 346 | canala
# Processing Record 347 | emba
# Processing Record 348 | deolali
# Processing Record 349 | larsnes
# Processing Record 350 | leshukonskoye
# Processing Record 351 | karratha
# Processing Record 352 | pauini
# Processing Record 353 | anaconda
# Processing Record 354 | moose factory
# Processing Record 355 | mwaya
# City not found. Skipping...
# Processing Record 356 | miri
# Processing Record 357 | kalmunai
# Processing Record 358 | geraldton
# Processing Record 359 | noyabrsk
# Processing Record 360 | urusha
# Processing Record 361 | lethem
# Processing Record 362 | aljezur
# Processing Record 363 | panguna
# Processing Record 364 | kleck
# City not found. Skipping...
# Processing Record 365 | asau
# City not found. Skipping...
# Processing Record 366 | nadym
# Processing Record 367 | sao felix do xingu
# Processing Record 368 | valparaiso
# Processing Record 369 | keti bandar
# Processing Record 370 | nador
# Processing Record 371 | samalaeulu
# City not found. Skipping...
# Processing Record 372 | hagerstown
# Processing Record 373 | waling
# City not found. Skipping...
# Processing Record 374 | matagami
# Processing Record 375 | pangai
# Processing Record 376 | silopi
# Processing Record 377 | lavrentiya
# Processing Record 378 | guane
# Processing Record 379 | klyuchi
# Processing Record 380 | omsukchan
# Processing Record 381 | champerico
# Processing Record 382 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 383 | flinders
# Processing Record 384 | mehamn
# Processing Record 385 | grindavik
# Processing Record 386 | caranavi
# Processing Record 387 | asopos
# Processing Record 388 | atambua
# Processing Record 389 | zhumadian
# Processing Record 390 | kinanah
# City not found. Skipping...
# Processing Record 391 | cabedelo
# Processing Record 392 | faanui
# Processing Record 393 | nioki
# Processing Record 394 | kyra
# City not found. Skipping...
# Processing Record 395 | fuerte
# Processing Record 396 | evensk
# Processing Record 397 | havre-saint-pierre
# Processing Record 398 | boksitogorsk
# Processing Record 399 | bolungarvik
# City not found. Skipping...
# Processing Record 400 | morros
# Processing Record 401 | ventspils
# Processing Record 402 | boueni
# Processing Record 403 | esperance
# Processing Record 404 | morondava
# Processing Record 405 | nova olimpia
# Processing Record 406 | narsaq
# Processing Record 407 | sao filipe
# Processing Record 408 | tupik
# Processing Record 409 | bardiyah
# City not found. Skipping...
# Processing Record 410 | bilibino
# Processing Record 411 | sioux lookout
# Processing Record 412 | tuatapere
# Processing Record 413 | barcelona
# Processing Record 414 | lambarene
# Processing Record 415 | belaya gora
# Processing Record 416 | qandala
# Processing Record 417 | yirol
# City not found. Skipping...
# Processing Record 418 | bambous virieux
# Processing Record 419 | husavik
# Processing Record 420 | pierre
# Processing Record 421 | gilazi
# City not found. Skipping...
# Processing Record 422 | miyako
# Processing Record 423 | mathbaria
# Processing Record 424 | mount pleasant
# Processing Record 425 | the pas
# Processing Record 426 | mayma
# Processing Record 427 | havoysund
# Processing Record 428 | borger
# Processing Record 429 | tautira
# Processing Record 430 | korla
# City not found. Skipping...
# Processing Record 431 | fortuna
# Processing Record 432 | sabha
# Processing Record 433 | college
# Processing Record 434 | palabuhanratu
# City not found. Skipping...
# Processing Record 435 | auki
# Processing Record 436 | chokurdakh
# Processing Record 437 | dafeng
# Processing Record 438 | port ellen
# City not found. Skipping...
# Processing Record 439 | pozhva
# Processing Record 440 | sakakah
# City not found. Skipping...
# Processing Record 441 | zyryanka
# Processing Record 442 | caravelas
# Processing Record 443 | luderitz
# Processing Record 444 | hwange
# Processing Record 445 | fraserburgh
# Processing Record 446 | inhambane
# Processing Record 447 | mazulskiy
# City not found. Skipping...
# Processing Record 448 | mosquera
# Processing Record 449 | westport
# Processing Record 450 | nemuro
# Processing Record 451 | gafanha da encarnacao
# Processing Record 452 | smiths falls
# Processing Record 453 | lekoni
# Processing Record 454 | santa vitoria do palmar
# Processing Record 455 | casa nova
# Processing Record 456 | waitati
# Processing Record 457 | quesnel
# Processing Record 458 | urdzhar
# City not found. Skipping...
# Processing Record 459 | blue springs
# Processing Record 460 | nome
# Processing Record 461 | marathon
# Processing Record 462 | spas-demensk
# Processing Record 463 | andenes
# City not found. Skipping...
# Processing Record 464 | jishou
# Processing Record 465 | hofn
# Processing Record 466 | sfantu gheorghe
# Processing Record 467 | paka
# Processing Record 468 | tutoia
# Processing Record 469 | montepuez
# Processing Record 470 | gunjur
# Processing Record 471 | nakapiripirit
# Processing Record 472 | anadyr
# Processing Record 473 | gondanglegi
# Processing Record 474 | marv dasht
# City not found. Skipping...
# Processing Record 475 | harper
# Processing Record 476 | noumea
# Processing Record 477 | mitsamiouli
# Processing Record 478 | aitape
# Processing Record 479 | inta
# Processing Record 480 | henties bay
# Processing Record 481 | breves
# Processing Record 482 | korsakov
# Processing Record 483 | dicabisagan
# Processing Record 484 | indramayu
# Processing Record 485 | disna
# City not found. Skipping...
# Processing Record 486 | cayenne
# Processing Record 487 | kemijarvi
# City not found. Skipping...
# Processing Record 488 | ningbo
# Processing Record 489 | andalan
# Processing Record 490 | saryozek
# Processing Record 491 | carutapera
# Processing Record 492 | linjiang
# Processing Record 493 | gornozavodsk
# Processing Record 494 | tambura
# City not found. Skipping...
# Processing Record 495 | port hardy
# Processing Record 496 | mahibadhoo
# Processing Record 497 | smoky lake
# Processing Record 498 | awbari
# Processing Record 499 | huainan
# Processing Record 500 | dunedin
# Processing Record 501 | praia
# Processing Record 502 | sydney
# Processing Record 503 | kugesi
# Processing Record 504 | whitehorse
# Processing Record 505 | powell river
# Processing Record 506 | talisay
# Processing Record 507 | aykhal
# Processing Record 508 | bacolod
# Processing Record 509 | vilela
# Processing Record 510 | belovo
# Processing Record 511 | manaus
# Processing Record 512 | santo angelo
# Processing Record 513 | linqiong
# Processing Record 514 | ilulissat
# Processing Record 515 | bandar-e anzali
# Processing Record 516 | dehui
# Processing Record 517 | gusau
# Processing Record 518 | ballina
# Processing Record 519 | havelock
# Processing Record 520 | aripuana
# Processing Record 521 | villacarrillo
# Processing Record 522 | xinan
# Processing Record 523 | pochutla
# Processing Record 524 | buariki
# City not found. Skipping...
# Processing Record 525 | puerto leguizamo
# Processing Record 526 | scarborough
# Processing Record 527 | santiago del estero
# Processing Record 528 | nabire
# Processing Record 529 | kitakata
# Processing Record 530 | rawson
# Processing Record 531 | padang
# Processing Record 532 | meyungs
# City not found. Skipping...
# Processing Record 533 | refojos de basto
# Processing Record 534 | malakal
# City not found. Skipping...
# Processing Record 535 | micheweni
# Processing Record 536 | gondal
# Processing Record 537 | ukiah
# Processing Record 538 | pisco
# Processing Record 539 | gollere
# City not found. Skipping...
# Processing Record 540 | adrar
# Processing Record 541 | namatanai
# Processing Record 542 | xuanhua
# Processing Record 543 | garissa
# Processing Record 544 | union
# Processing Record 545 | alugan
# Processing Record 546 | uporovo
# Processing Record 547 | derzhavinsk
# Processing Record 548 | popondetta
# Processing Record 549 | blonduos
# City not found. Skipping...
# Processing Record 550 | poso
# Processing Record 551 | lujan
# Processing Record 552 | ishigaki
# Processing Record 553 | komsomolskiy
# Processing Record 554 | san quintin
# Processing Record 555 | price
# Processing Record 556 | mayumba
# Processing Record 557 | nanortalik
# Processing Record 558 | itarema
# Processing Record 559 | kangaatsiaq
# Processing Record 560 | nizhyn
# Processing Record 561 | gari
# Processing Record 562 | verkhnyaya inta
# Processing Record 563 | viedma
# Processing Record 564 | srednekolymsk
# Processing Record 565 | shubarkuduk
# Processing Record 566 | daru
# Processing Record 567 | ilinskiy
# Processing Record 568 | port macquarie
# Processing Record 569 | pop
# Processing Record 570 | bandarbeyla
# Processing Record 571 | gotsu
# Processing Record 572 | kattivakkam
# Processing Record 573 | tonantins
# Processing Record 574 | grand-lahou
# Processing Record 575 | kenai
# Processing Record 576 | byadgi
# Processing Record 577 | vilhena
# Processing Record 578 | nichinan
# Processing Record 579 | tarazona
# Processing Record 580 | talara
# Processing Record 581 | faya
# Processing Record 582 | ponnani
# Processing Record 583 | chinhoyi
# Processing Record 584 | ovalle
# Processing Record 585 | medina
# Processing Record 586 | bay roberts
# Processing Record 587 | alofi
# Processing Record 588 | sandpoint
# Processing Record 589 | dubbo
# Processing Record 590 | emerald
# Processing Record 591 | manggar
# Processing Record 592 | ladario
# Processing Record 593 | the valley
# Processing Record 594 | villanueva de la serena
# Processing Record 595 | santa ana
# Processing Record 596 | luanda
# Processing Record 597 | tabiauea
# City not found. Skipping...
# Processing Record 598 | ranong
# Processing Record 599 | itaberaba
# Processing Record 600 | rungata
# City not found. Skipping...
# Processing Record 601 | aksarka
# Processing Record 602 | eskil
# Processing Record 603 | santa isabel do rio negro
# Processing Record 604 | khormuj
# City not found. Skipping...
# Processing Record 605 | mangan
# Processing Record 606 | tommot
# Processing Record 607 | kulhudhuffushi
# Processing Record 608 | kaeo
# Processing Record 609 | santa paula
# Processing Record 610 | bonthe
# Processing Record 611 | matara
# Processing Record 612 | kloulklubed
# Processing Record 613 | vila
# Processing Record 614 | ponta delgada
# Processing Record 615 | manadhoo
# Processing Record 616 | paredon
# Processing Record 617 | mehkar
# Processing Record 618 | grodzisk wielkopolski
# Processing Record 619 | mana
# Processing Record 620 | zhigansk
# Processing Record 621 | lisakovsk
# Processing Record 622 | tuchola
# Processing Record 623 | laguna
# Processing Record 624 | pundaguitan

# %%
weather_df
# Out:
#                   City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0      barrancabermeja         40      CO  1553374800       78   7.07  -73.85
# 1                 hilo         90      US  1553377273       54  19.71 -155.08
# 2             cidreira          0      BR  1553377003       79 -30.17  -50.22
# 3           georgetown         20      GY  1553374800       70    6.8  -58.16
# 4             impfondo         80      CD  1553377003       91   1.62   18.06
# 5              rikitea         64      PF  1553376743       97 -23.12 -134.97
# 6              voyvozh         12      RU  1553377333       78  62.89   54.96
# 7               namibe         48      AO  1553376884      100 -15.19   12.15
# 8               torbay         90      CA  1553376891       93  47.66  -52.73
# 9              chimore         32      BO  1553377004       78 -16.98  -65.13
# 10              hasaki         20      JP  1553374941       80  35.73  140.83
# 11              pyshma          0      RU  1553377334       62  56.95   63.25
# 12          bredasdorp         44      ZA  1553376690       83 -34.53   20.04
# 13           mogadishu         76      SO  1553376913      100   2.04   45.34
# 14           busselton         68      AU  1553376810       56 -33.64  115.35
# 15            hermanus         76      ZA  1553376690       91 -34.42   19.24
# 16           saskylakh          0      RU  1553377005       38  71.97  114.09
# 17         new norfolk         20      AU  1553377334       72 -42.78  147.06
# 18    praia da vitoria         75      PT  1553376837       81  38.73  -27.07
# 19              hobart         20      AU  1553377214       72 -42.88  147.33
# 20   sao joao da barra         75      BR  1553374800       78 -21.64  -41.05
# 21           cape town          0      ZA  1553376790       88 -33.93   18.42
# 22             sarakhs          0      TM  1553374800       87  36.54   61.16
# 23        punta arenas         75      CL  1553376791       76 -53.16  -70.91
# 24              barrow         80      AR  1553377007       96 -38.31  -60.23
# 25        puerto ayora         20      EC  1553376689       74  -0.74  -90.35
# 26              albany          1      US  1553376840       40  42.65  -73.75
# 27               sitka          0      US  1553376707       43  37.17  -99.65
# 28             russell          0      AR  1553374800       32 -33.01   -68.8
# 29           jamestown         92      AU  1553377008       86 -33.21   138.6
# ..                 ...        ...     ...         ...      ...    ...     ...
# 594                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 595                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 596                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 597                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 598                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 599                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 600                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 601                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 602                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 603                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 604                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 605                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 606                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 607                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 608                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 609                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 610                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 611                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 612                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 613                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 614                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 615                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 616                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 617                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 618                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 619                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 620                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 621                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 622                NaN        NaN     NaN         NaN      NaN    NaN     NaN
# 623                NaN        NaN     NaN         NaN      NaN    NaN     NaN
#
#     Max Temp Min Temp Avg Temp Wind Speed
# 0         28       28       28       1.12
# 1         26    21.67    23.94        4.1
# 2      21.67    21.67    21.67       2.42
# 3         29       29       29        5.1
# 4      24.87    24.87    24.87       1.32
# 5      26.47    26.47    26.47       8.62
# 6      -4.78    -4.78    -4.78       4.37
# 7      25.72    25.72    25.72       2.42
# 8       5.56     3.89      4.9        2.1
# 9      25.37    25.37    25.37       0.52
# 10        -1    -2.78    -1.94        1.5
# 11     -8.83    -8.83    -8.83       1.22
# 12        21    19.44    20.07          1
# 13     27.47    27.47    27.47       6.62
# 14     11.67     8.89    10.58       5.67
# 15     19.44    18.89    19.13       1.52
# 16    -31.88   -31.88   -31.88       1.32
# 17     18.89    13.89    16.37        3.6
# 18     12.22       12    12.12      13.47
# 19     18.89    13.89    16.37        3.6
# 20        26       26       26        3.1
# 21     21.11    17.78    19.12        4.1
# 22         9        9        9        2.1
# 23        12    11.67    11.82        4.6
# 24     18.02    18.02    18.02       6.37
# 25        29    26.67    27.83        5.1
# 26      4.44    -2.22     1.31        8.7
# 27     18.89    18.89    18.89       3.13
# 28        28       28       28        2.1
# 29     17.92    17.92    17.92       4.67
# ..       ...      ...      ...        ...
# 594      NaN      NaN      NaN        NaN
# 595      NaN      NaN      NaN        NaN
# 596      NaN      NaN      NaN        NaN
# 597      NaN      NaN      NaN        NaN
# 598      NaN      NaN      NaN        NaN
# 599      NaN      NaN      NaN        NaN
# 600      NaN      NaN      NaN        NaN
# 601      NaN      NaN      NaN        NaN
# 602      NaN      NaN      NaN        NaN
# 603      NaN      NaN      NaN        NaN
# 604      NaN      NaN      NaN        NaN
# 605      NaN      NaN      NaN        NaN
# 606      NaN      NaN      NaN        NaN
# 607      NaN      NaN      NaN        NaN
# 608      NaN      NaN      NaN        NaN
# 609      NaN      NaN      NaN        NaN
# 610      NaN      NaN      NaN        NaN
# 611      NaN      NaN      NaN        NaN
# 612      NaN      NaN      NaN        NaN
# 613      NaN      NaN      NaN        NaN
# 614      NaN      NaN      NaN        NaN
# 615      NaN      NaN      NaN        NaN
# 616      NaN      NaN      NaN        NaN
# 617      NaN      NaN      NaN        NaN
# 618      NaN      NaN      NaN        NaN
# 619      NaN      NaN      NaN        NaN
# 620      NaN      NaN      NaN        NaN
# 621      NaN      NaN      NaN        NaN
# 622      NaN      NaN      NaN        NaN
# 623      NaN      NaN      NaN        NaN
#
# [624 rows x 11 columns]

# %%
weather_df.dropna(how='all',inplace=True)
weather_df
# Out:
#                           City Cloudiness Country        Date Humidity    Lat  \
# 0              barrancabermeja         40      CO  1553374800       78   7.07
# 1                         hilo         90      US  1553377273       54  19.71
# 2                     cidreira          0      BR  1553377003       79 -30.17
# 3                   georgetown         20      GY  1553374800       70    6.8
# 4                     impfondo         80      CD  1553377003       91   1.62
# 5                      rikitea         64      PF  1553376743       97 -23.12
# 6                      voyvozh         12      RU  1553377333       78  62.89
# 7                       namibe         48      AO  1553376884      100 -15.19
# 8                       torbay         90      CA  1553376891       93  47.66
# 9                      chimore         32      BO  1553377004       78 -16.98
# 10                      hasaki         20      JP  1553374941       80  35.73
# 11                      pyshma          0      RU  1553377334       62  56.95
# 12                  bredasdorp         44      ZA  1553376690       83 -34.53
# 13                   mogadishu         76      SO  1553376913      100   2.04
# 14                   busselton         68      AU  1553376810       56 -33.64
# 15                    hermanus         76      ZA  1553376690       91 -34.42
# 16                   saskylakh          0      RU  1553377005       38  71.97
# 17                 new norfolk         20      AU  1553377334       72 -42.78
# 18            praia da vitoria         75      PT  1553376837       81  38.73
# 19                      hobart         20      AU  1553377214       72 -42.88
# 20           sao joao da barra         75      BR  1553374800       78 -21.64
# 21                   cape town          0      ZA  1553376790       88 -33.93
# 22                     sarakhs          0      TM  1553374800       87  36.54
# 23                punta arenas         75      CL  1553376791       76 -53.16
# 24                      barrow         80      AR  1553377007       96 -38.31
# 25                puerto ayora         20      EC  1553376689       74  -0.74
# 26                      albany          1      US  1553376840       40  42.65
# 27                       sitka          0      US  1553376707       43  37.17
# 28                     russell          0      AR  1553374800       32 -33.01
# 29                   jamestown         92      AU  1553377008       86 -33.21
# ..                         ...        ...     ...         ...      ...    ...
# 525                    ladario          0      PT  1553377051       67   40.7
# 526                 the valley         20      AI  1553376828       65  18.22
# 527    villanueva de la serena         12      ES  1553377262       46  38.97
# 528                  santa ana         75      SV  1553376915       24  13.99
# 529                     luanda         76      AO  1553377458      100  -8.83
# 530                     ranong          8      TH  1553377458      100   9.96
# 531                  itaberaba         92      BR  1553377458       89 -12.52
# 532                    aksarka          0      RU  1553377458       63  66.56
# 533                      eskil         56      TR  1553377459       67   38.4
# 534  santa isabel do rio negro         44      BR  1553377459       90  -0.41
# 535                     mangan          0      IN  1553377459       46   27.5
# 536                     tommot         80      RU  1553377459       87  58.97
# 537             kulhudhuffushi          0      MV  1553377460      100   6.62
# 538                       kaeo          0      NZ  1553377089       89  -35.1
# 539                santa paula         90      US  1553377453       59  34.35
# 540                     bonthe         92      SL  1553377460       72   7.53
# 541                     matara         48      PE  1553377461       69 -13.74
# 542                kloulklubed         40      PW  1553374200       88   7.04
# 543                       vila          0      IT  1553377449       70  45.18
# 544              ponta delgada         40      PT  1553377434       81  37.73
# 545                   manadhoo          0      MV  1553377462       99   5.77
# 546                    paredon         88      BO  1553377462       70 -18.93
# 547                     mehkar          0      IN  1553377462       57  20.15
# 548      grodzisk wielkopolski          0      PL  1553377434       81  52.23
# 549                       mana          0      RS  1553374800       70  43.52
# 550                   zhigansk         56      RU  1553377463       82  66.77
# 551                  lisakovsk         92      KZ  1553377463       75  52.55
# 552                    tuchola          0      PL  1553377414       75  53.59
# 553                     laguna          5      MX  1553373660       28  27.52
# 554                pundaguitan          8      PH  1553377464      100   6.37
#
#         Lng Max Temp Min Temp Avg Temp Wind Speed
# 0    -73.85       28       28       28       1.12
# 1   -155.08       26    21.67    23.94        4.1
# 2    -50.22    21.67    21.67    21.67       2.42
# 3    -58.16       29       29       29        5.1
# 4     18.06    24.87    24.87    24.87       1.32
# 5   -134.97    26.47    26.47    26.47       8.62
# 6     54.96    -4.78    -4.78    -4.78       4.37
# 7     12.15    25.72    25.72    25.72       2.42
# 8    -52.73     5.56     3.89      4.9        2.1
# 9    -65.13    25.37    25.37    25.37       0.52
# 10   140.83       -1    -2.78    -1.94        1.5
# 11    63.25    -8.83    -8.83    -8.83       1.22
# 12    20.04       21    19.44    20.07          1
# 13    45.34    27.47    27.47    27.47       6.62
# 14   115.35    11.67     8.89    10.58       5.67
# 15    19.24    19.44    18.89    19.13       1.52
# 16   114.09   -31.88   -31.88   -31.88       1.32
# 17   147.06    18.89    13.89    16.37        3.6
# 18   -27.07    12.22       12    12.12      13.47
# 19   147.33    18.89    13.89    16.37        3.6
# 20   -41.05       26       26       26        3.1
# 21    18.42    21.11    17.78    19.12        4.1
# 22    61.16        9        9        9        2.1
# 23   -70.91       12    11.67    11.82        4.6
# 24   -60.23    18.02    18.02    18.02       6.37
# 25   -90.35       29    26.67    27.83        5.1
# 26   -73.75     4.44    -2.22     1.31        8.7
# 27   -99.65    18.89    18.89    18.89       3.13
# 28    -68.8       28       28       28        2.1
# 29    138.6    17.92    17.92    17.92       4.67
# ..      ...      ...      ...      ...        ...
# 525   -7.74    16.67       10    14.07       1.87
# 526  -63.06       28       26    26.84        5.7
# 527    -5.8    15.56    15.56    15.56       3.13
# 528  -89.56       32    30.56    31.29        3.1
# 529   13.24    25.77    25.77    25.77       2.32
# 530   98.62    27.77    27.77    27.77       2.32
# 531  -40.31    24.87    24.87    24.87       1.22
# 532    67.8   -15.73   -15.73   -15.73       1.97
# 533   33.41     4.77     4.77     4.77       6.32
# 534  -65.02    27.87    27.87    27.87       1.77
# 535   88.54    -8.88    -8.88    -8.88       0.72
# 536  126.27    -9.13    -9.13    -9.13       1.12
# 537   73.07    28.87    28.87    28.87       2.32
# 538  173.78    19.44    19.44    19.44       1.79
# 539 -119.06    18.33    11.67    16.24        5.1
# 540   -12.5    28.37    28.37    28.37       2.32
# 541   -72.9    13.07    13.07    13.07       1.07
# 542  134.26       24       24       24        2.1
# 543     8.4    15.56     8.33    12.32        2.6
# 544  -25.67    12.78       12    12.41        8.2
# 545   73.38    29.37    29.37    29.37       3.07
# 546  -65.16    14.77    14.77    14.77       1.22
# 547   76.57    19.57    19.57    19.57       1.17
# 548   16.36     9.44     7.22      8.2        4.6
# 549   20.24        7        4     5.42        0.5
# 550  123.37   -13.58   -13.58   -13.58       3.67
# 551   62.49    -3.03    -3.03    -3.03       1.17
# 552   17.86     7.78     4.44     6.08        3.6
# 553 -110.01       27       27       27        4.6
# 554  126.17    26.12    26.12    26.12       4.02
#
# [555 rows x 11 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
output_data_file = "output_data/cities.csv"
weather_df.to_csv(output_data_file, index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis=weather_df['Lat']
data=weather_df['Avg Temp']
plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.5)
plt.grid()
plt.title("Latitude vs. Average Temperature 3/23/2019")
plt.xlabel("Latitude")
plt.ylabel("Average Temperature (C)")
# Out:
# Text(0,0.5,'Average Temperature (C)')

# %%
weather_df_humidity=weather_df.drop(weather_df.loc[weather_df['Humidity']>100].index)
x_axis=weather_df_humidity['Lat']
data=weather_df_humidity['Humidity']
plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.5)
plt.grid()
plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Out:
# Text(0,0.5,'Humidity (%)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis=weather_df['Lat']
data=weather_df['Cloudiness']
plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.5)
plt.grid()
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Out:
# Text(0,0.5,'Cloudiness (%)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis=weather_df['Lat']
data=weather_df['Wind Speed']
plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.5)
plt.grid()
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Out:
# Text(0,0.5,'Wind Speed (mph)')
